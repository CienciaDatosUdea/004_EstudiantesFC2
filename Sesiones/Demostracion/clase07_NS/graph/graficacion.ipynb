# %%
import numpy as np
import matplotlib.pylab as plt

# %%
d = np.loadtxt("../datos/datos.txt")
# Out:
# array([[0.      , 0.      ],
#        [0.      , 0.222222],
#        [0.      , 0.444444],
#        [0.      , 0.666667],
#        [0.      , 0.888889],
#        [0.      , 1.11111 ],
#        [0.      , 1.33333 ],
#        [0.      , 1.55556 ],
#        [0.      , 1.77778 ],
#        [0.      , 2.      ],
#        [0.222222, 0.      ],
#        [0.222222, 0.222222],
#        [0.222222, 0.444444],
#        [0.222222, 0.666667],
#        [0.222222, 0.888889],
#        [0.222222, 1.11111 ],
#        [0.222222, 1.33333 ],
#        [0.222222, 1.55556 ],
#        [0.222222, 1.77778 ],
#        [0.222222, 2.      ],
#        [0.444444, 0.      ],
#        [0.444444, 0.222222],
#        [0.444444, 0.444444],
#        [0.444444, 0.666667],
#        [0.444444, 0.888889],
#        [0.444444, 1.11111 ],
#        [0.444444, 1.33333 ],
#        [0.444444, 1.55556 ],
#        [0.444444, 1.77778 ],
#        [0.444444, 2.      ],
#        [0.666667, 0.      ],
#        [0.666667, 0.222222],
# ...
