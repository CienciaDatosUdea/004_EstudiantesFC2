# %%
# Importamos el módulo sim_fdtd.py y le damos el alias "sfd"
import sim_fdtd as sfd
import matplotlib.pyplot as plt

# %%
sfd.generar_animacion_onda(
    ruta_datos="../resultados_periodico.txt",
    titulo="Propagación de Onda (Bordes Periódicos, β=0.5)",
    nombre_salida_gif="animacion_periodica.gif"
)
# Out:
# Guardando animación en 'animacion_periodica.gif'...
# Animación guardada con éxito.

# %% [markdown]
# Inicialmente, la onda se desplaza por la malla de forma predecible, conservando su perfil sinusoidal y su energía. Sin embargo, el método numérico evidencia una inestabilidad latente que se manifiesta a largo plazo. Al superar los 150-200 pasos de tiempo, comienzan a surgir "ruidos" o artefactos de alta frecuencia.

# %%
sfd.generar_animacion_onda(
    ruta_datos="../resultados_absorbente.txt",
    titulo="Propagación de Onda (Bordes Absorbentes, β=0.5)",
    nombre_salida_gif="animacion_absorbente.gif"
)
# Out:
# Guardando animación en 'animacion_absorbente.gif'...
# Animación guardada con éxito.

# %% [markdown]
# De manera análoga al caso anterior, la simulación con fronteras absorbentes también sucumbe a la inestabilidad. A medida que el pulso de la onda alcanza los extremos de la malla, la interacción con la condición de borde absorbente introduce pequeñas imprecisiones numéricas.

# %%
sfd.generar_animacion_onda(
    ruta_datos="../resultados_inestable.txt",
    titulo="Prueba de Inestabilidad Numérica (β=1.0)",
    nombre_salida_gif="animacion_inestable.gif"
)
# Out:
# Guardando animación en 'animacion_inestable.gif'...
# Animación guardada con éxito.

# %% [markdown]
# En este escenario, el colapso de la simulación es prácticamente instantáneo. Desde las primeras iteraciones, la amplitud de los campos sufre un crecimiento explosivo, divergiendo de forma exponencial.
