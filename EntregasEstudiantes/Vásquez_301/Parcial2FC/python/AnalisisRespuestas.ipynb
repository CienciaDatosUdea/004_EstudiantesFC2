# %%
import sim_fdtd
import matplotlib.pyplot as plt

# %%
sim_fdtd.create_fdtd_animation(
    data_filepath="../fdtd_periodic_data.txt", 
    title="Problema 1.1: Fronteras Periódicas (β=0.5)",
    output_filename="periodic_animation.gif" 
)
# Out:
# Animación guardada en periodic_animation.gif

# %% [markdown]
# En los pasos iniciales de la simulación (aproximadamente de t=0 a t=150), la onda sinusoidal se propaga a través de la red como se esperaba, manteniendo su forma y amplitud. Sin embargo, a largo plazo, la simulación demuestra ser numéricamente inestable. Después de aproximadamente 150-200 pasos de tiempo, la solución degenera en oscilaciones de alta frecuencia que corrompen completamente la forma de la onda.

# %%
# Visualizamos la simulación con fronteras absorbentes (E=H=0).
sim_fdtd.create_fdtd_animation(
    data_filepath="../fdtd_absorbing_data.txt", 
    title="Problema 1.2(a): Fronteras Absorbentes (β=0.5)",
    output_filename="absorbing_animation.gif"
)
# Out:
# Animación guardada en absorbing_animation.gif

# %% [markdown]
# El comportamiento observado es similar al del caso periódico. La onda viaja hacia las fronteras y, al interactuar con ellas, se introducen errores numéricos. Estos errores son amplificados por el algoritmo inestable, generando rápidamente ruido de alta frecuencia que se origina en los bordes y se propaga hacia el centro.

# %%
# Visualizamos la simulación inestable.
sim_fdtd.create_fdtd_animation(
    data_filepath="../fdtd_unstable_data.txt", 
    title="Problema 1.2(b): Inestabilidad Numérica (β=1.0)",
    output_filename="unstable_animation.gif"
)
# Out:
# Animación guardada en unstable_animation.gif

# %% [markdown]
# La simulación colapsa de forma inmediata. La amplitud de los campos crece exponencialmente en muy pocos pasos de tiempo, alcanzando valores de infinito
