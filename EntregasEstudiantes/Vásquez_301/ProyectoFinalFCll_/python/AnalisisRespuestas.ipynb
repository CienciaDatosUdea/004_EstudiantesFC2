# %%
import numpy as np
import matplotlib.pyplot as plt
from plots import *
# %matplotlib inline

# %% [markdown]
# # Análisis de Resultados de la Simulación

# %% [markdown]
# ## Magnetostática
# ### Potencial "Camelback"

# %%
# Graficar los datos del potencial
plot_camelback("../data/camelback.txt")

# %% [markdown]
# ### Análisis Paramétrico

# %%
# Grafica los datos del barrido de parámetros
plot_param_sweep("../data/paramsweep.txt")

# %% [markdown]
# ## Dinámica de la Varilla
# ### Simulación de la Oscilación

# %%
# Grafica la trayectoria de la oscilación
plot_oscillation("../data/oscillation.txt")

# %% [markdown]
# ### Espectro de Frecuencia y Medición del Período

# %%
# Calcula y grafica la FFT, y guarda el período medido
T_z_measured = plot_fft_spectrum("../data/oscillation.txt")
# Out:
# La frecuencia dominante de la oscilación es: 0.6793 Hz
# El período 'medido' de la simulación es: T_z = 1.4721 s

# %% [markdown]
# ### Verificación del Modelo

# %%
# Parámetros conocidos de la simulación de C++

y0_from_cpp = 0.0022344 
a_param = 0.0032
chi_param = -2.0e-4

simulation_results = {
    "y0": y0_from_cpp,
    "a": a_param,
    "T_z": T_z_measured,
    "chi": chi_param
}

# Curvas teóricas y el punto de la simulación
plot_validation_curves("../data/validation_curves.txt", simulation_results)
